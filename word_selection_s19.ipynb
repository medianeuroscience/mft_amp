# %%
import random
import pandas as pd
import numpy as np

# %%
words = pd.read_csv("exp_files_s19/condition_files/words4exp.csv")
symbols = pd.read_csv("exp_files_s19/condition_files/symbols.csv")
memtask_words = pd.read_csv("exp_files_s19/condition_files/mem_task_words.csv")

# %% [markdown]
# # Generating Word Lists
# In this block we want to generate a dictionary of lists that correspond with the word categories in the `words4exp.csv` file. This will allow us to sample a subset of the words from each category to show in the AMP and then use the words that were **not** in the AMP for the lexical decision making task. This code will be pasted into PsychoPy in order to generate the word lists for each participant.
#
# - 70 moral words (14 from each foundation), 10 nonwords, and 2 control words will go into the AMP.
# - 82 symbols will go into the AMP
# - 50 moral words, 50 neutral words, and 100 nonwords will go into the LDT
#
# First, we will divide up the dataframe based on word category, sorting words from each category into separate dictionary keys in a dictionary we'll call `unique_cats`.

# %%
unique_cats = {k:None for k in words.category.unique()}
for k,v in unique_cats.items():
    unique_cats[k] = list(words[words.category == k].index.values)

# %% [markdown]
# Now we will draw a random sample of 7 words per MFD category, 10 nonwords, and the 2 controls for the AMP. What's left we'll put into the LDT.

# %%
full_amp_words = {k:None for k in unique_cats.keys() if k != "neutral"}
full_ldt_words = {k:None for k in unique_cats.keys()}
for k,v in unique_cats.items():
    if "." in str(k): 
        full_amp_words[k] = random.sample(unique_cats[k],7)
        full_ldt_words[k] = [x for x in unique_cats[k] if x not in full_amp_words[k]]
    if k == "nonword":
        full_amp_words[k] = random.sample(unique_cats[k],10)
        full_ldt_words[k] = [x for x in unique_cats[k] if x not in full_amp_words[k]]
    if k =="control":
        full_amp_words[k] = unique_cats[k]
    if k == "neutral":
        full_ldt_words[k] = unique_cats[k]

# %% [markdown]
# ## Generating the final list of words for the AMP

# %%
amp_primes = []
amp_symbols = range(0,82)
for k,v in full_amp_words.items():
    for i in v:
        amp_primes.append(i)

# %%
#We should have 82 total matched pairs in the amp.
len(amp_symbols)
# Out:
# 82

# %%
# Pulling the words, correct answers, and categories for all of the indices for our moral words plus our ten nonword controls
AMP_words = words.loc[amp_primes].words.values
AMP_corr_ans = words.loc[amp_primes].correct_amp.values
AMP_category = words.loc[amp_primes].category.values
AMP_masks = words.loc[amp_primes].masks.values

#pulling the nonwords and masks for our targets that weren't selected to be included in the prime
AMP_symbols = symbols.loc[amp_symbols].symbol.values

# %% [markdown]
# Now we will create a couple of dataframes that will contain the word, the correct answer, the nonword, and the mask. We will then shuffle the words and the nonwords so that they aren't in the same order for every participant. Finally, we'll concatenate them together.

# %%
# df1 is the words that will be used as primes and their associated categories and correct answers

df1 = pd.DataFrame(
    {'words': AMP_words.tolist(),
     'corr_ans': AMP_corr_ans.tolist(),
     'category': AMP_category.tolist(),
     'masks': AMP_masks.tolist()
    })

# df2 is the nonwords that will be used as targets and their associated masks

df2 = pd.DataFrame(
     {'symbols': AMP_symbols.tolist()
    })

# Shuffling the words once and then generating four 

primes_rep1 = df1.sample(frac=1).reset_index(drop=True)
targets_rep1 = df2.sample(frac=1).reset_index(drop=True)

primes_rep2 = df1.sample(frac=1).reset_index(drop=True)
targets_rep2 = df2.sample(frac=1).reset_index(drop=True)

primes_rep3 = df1.sample(frac=1).reset_index(drop=True)
targets_rep3 = df2.sample(frac=1).reset_index(drop=True)

primes_rep4 = df1.sample(frac=1).reset_index(drop=True)
targets_rep4 = df2.sample(frac=1).reset_index(drop=True)

# Concatenating all of the primes and targets horizontally

rep1 = pd.concat([primes_rep1,targets_rep1], axis = 1)
rep1.to_csv("exp_files_s19/condition_files/AMP_rep1.csv")

rep2 = pd.concat([primes_rep2,targets_rep2], axis = 1)
rep1.to_csv("exp_files_s19/condition_files/AMP_rep2.csv")

rep3 = pd.concat([primes_rep3,targets_rep3], axis = 1)
rep1.to_csv("exp_files_s19/condition_files/AMP_rep3.csv")

rep4 = pd.concat([primes_rep4,targets_rep4], axis = 1)
rep1.to_csv("exp_files_s19/condition_files/AMP_rep4.csv")

# Concatenating all of the reps horizontally

df_full = pd.concat([rep1,rep2,rep3,rep4], axis = 0)

# %% [markdown]
# Finally, we will write this to a CSV that will be used for this participant and then deleted.

# %%
df_full.reset_index(inplace=True, drop=True)
df_full
# Out:
#           words corr_ans          category       masks  \
# 0       torture    right         care.vice     &&&&&&&
# 1        praise     left  authority.virtue      &&&&&&
# 2         death    right         care.vice       &&&&&
# 3        sexual    right     sanctity.vice      &&&&&&
# 4      violence    right         care.vice    &&&&&&&&
# 5       promote     left   sanctity.virtue     &&&&&&&
# 6    threatened    right     fairness.vice  &&&&&&&&&&
# 7        police    right    authority.vice      &&&&&&
# 8       charges    right     fairness.vice     &&&&&&&
# 9     encourage     left  authority.virtue   &&&&&&&&&
# 10         died    right         care.vice        &&&&
# 11        party     left    loyalty.virtue       &&&&&
# 12         army    right      loyalty.vice        &&&&
# 13        great     left    loyalty.virtue       &&&&&
# 14   protesters    right    authority.vice  &&&&&&&&&&
# 15       killed    right         care.vice      &&&&&&
# 16       blamed    right      loyalty.vice      &&&&&&
# 17      gryssed      NaN           nonword     &&&&&&&
# 18      dignity     left   sanctity.virtue     &&&&&&&
# 19    agreement     left   fairness.virtue   &&&&&&&&&
# 20   violations    right     sanctity.vice  &&&&&&&&&&
# 21      arrests    right    authority.vice     &&&&&&&
# 22         care     left       care.virtue        &&&&
# 23         free     left   fairness.virtue        &&&&
# 24         fair     left   fairness.virtue        &&&&
# 25    wraughsed      NaN           nonword   &&&&&&&&&
# 26     betrayal    right      loyalty.vice    &&&&&&&&
# 27         love     left    loyalty.virtue        &&&&
# 28     actively     left  authority.virtue    &&&&&&&&
# 29         help     left       care.virtue        &&&&
# ..          ...      ...               ...         ...
# 298  protesters    right    authority.vice  &&&&&&&&&&
# 299     friends     left    loyalty.virtue     &&&&&&&
# 300      sexual    right     sanctity.vice      &&&&&&
# 301     troalde      NaN           nonword     &&&&&&&
# 302  celebrated     left  authority.virtue  &&&&&&&&&&
# 303        love     left    loyalty.virtue        &&&&
# 304     improve     left       care.virtue     &&&&&&&
# 305      troops    right      loyalty.vice      &&&&&&
# 306        drug    right     sanctity.vice        &&&&
# 307         men    right      loyalty.vice         &&&
# 308      prison    right     fairness.vice      &&&&&&
# 309     benefit     left   fairness.virtue     &&&&&&&
# 310     sharing     left    loyalty.virtue     &&&&&&&
# 311        care     left       care.virtue        &&&&
# 312     restore     left       care.virtue     &&&&&&&
# 313   terrorist    right      loyalty.vice   &&&&&&&&&
# 314      serial    right     sanctity.vice      &&&&&&
# 315     victims    right         care.vice     &&&&&&&
# 316     promote     left   sanctity.virtue     &&&&&&&
# 317      groups    right      loyalty.vice      &&&&&&
# 318     arrests    right    authority.vice     &&&&&&&
# 319      freazz      NaN           nonword      &&&&&&
# 320     charges    right     fairness.vice     &&&&&&&
# 321    actively     left  authority.virtue    &&&&&&&&
# 322         win     left   fairness.virtue         &&&
# 323     phlaizz      NaN           nonword     &&&&&&&
# 324      rebels    right    authority.vice      &&&&&&
# 325     freedom     left   sanctity.virtue     &&&&&&&
# 326  terrorists    right     fairness.vice  &&&&&&&&&&
# 327    squintce      NaN           nonword    &&&&&&&&
#
#                           symbols
# 0    images/symbols/symbol_55.png
# 1    images/symbols/symbol_12.png
# 2    images/symbols/symbol_27.png
# 3     images/symbols/symbol_1.png
# 4    images/symbols/symbol_15.png
# 5    images/symbols/symbol_42.png
# 6     images/symbols/symbol_2.png
# 7    images/symbols/symbol_18.png
# 8    images/symbols/symbol_46.png
# 9    images/symbols/symbol_81.png
# 10   images/symbols/symbol_67.png
# 11   images/symbols/symbol_39.png
# 12   images/symbols/symbol_58.png
# 13   images/symbols/symbol_80.png
# 14    images/symbols/symbol_4.png
# 15   images/symbols/symbol_77.png
# 16   images/symbols/symbol_59.png
# 17   images/symbols/symbol_10.png
# 18   images/symbols/symbol_57.png
# 19   images/symbols/symbol_69.png
# 20   images/symbols/symbol_68.png
# 21   images/symbols/symbol_29.png
# 22   images/symbols/symbol_17.png
# 23   images/symbols/symbol_43.png
# 24   images/symbols/symbol_53.png
# 25   images/symbols/symbol_26.png
# 26   images/symbols/symbol_24.png
# 27   images/symbols/symbol_60.png
# 28   images/symbols/symbol_64.png
# 29   images/symbols/symbol_28.png
# ..                            ...
# 298  images/symbols/symbol_37.png
# 299  images/symbols/symbol_38.png
# 300   images/symbols/symbol_7.png
# 301  images/symbols/symbol_75.png
# 302  images/symbols/symbol_12.png
# 303  images/symbols/symbol_54.png
# 304  images/symbols/symbol_40.png
# 305  images/symbols/symbol_72.png
# 306  images/symbols/symbol_79.png
# 307  images/symbols/symbol_61.png
# 308   images/symbols/symbol_4.png
# 309  images/symbols/symbol_63.png
# 310  images/symbols/symbol_13.png
# 311  images/symbols/symbol_34.png
# 312  images/symbols/symbol_43.png
# 313  images/symbols/symbol_26.png
# 314  images/symbols/symbol_23.png
# 315  images/symbols/symbol_39.png
# 316  images/symbols/symbol_58.png
# 317  images/symbols/symbol_33.png
# 318  images/symbols/symbol_51.png
# 319   images/symbols/symbol_3.png
# 320  images/symbols/symbol_11.png
# 321  images/symbols/symbol_36.png
# 322  images/symbols/symbol_65.png
# 323  images/symbols/symbol_32.png
# 324  images/symbols/symbol_78.png
# 325  images/symbols/symbol_21.png
# 326  images/symbols/symbol_55.png
# 327  images/symbols/symbol_71.png
#
# [328 rows x 5 columns]

# %%
df_full.to_csv("exp_files_s19/condition_files/AMP_conditions.csv")

# %% [markdown]
# ## Lexical Decision Task
#
# In the Lexical Decision Making tasks (LDT) we will have LDT 50 moral words, 50 neutral words, 100 nonwords

# %%
ldt_wordlist = []
for k,v in full_ldt_words.items():
    if k != "control":
        for i in v:
            ldt_wordlist.append(i)
            
# Pulling the words, correct answers, categories, & masks for all of the indices for our words
LDT_words = words.loc[ldt_wordlist].words.values
LDT_corr = words.loc[ldt_wordlist].correct_ldt.values
LDT_category = words.loc[ldt_wordlist].category.values
LDT_masklist = words.loc[ldt_wordlist].masks.values
            
df_ldt = pd.DataFrame(
    {'words': LDT_words.tolist(),
     'corr_ans': LDT_corr.tolist(),
     'category': LDT_category.tolist(),
     'mask': LDT_masklist.tolist()
    })

# %%
# We should have 200 LDT words
len(LDT_words)
# Out:
# 200

# %%
df_ldt.to_csv("exp_files_s19/condition_files/LDT_conditions.csv")

# %% [markdown]
# ## Memory Task
#
# In this task, we will show the participant words and nonwords that they saw during the AMP along with words and nonwords that they did not see. Thus, we should repeat the AMP primes list, but also create another list of words and nonwords that were not seen.

# %%
memtask_wordlist = memtask_words.words.values
memtask_cats = memtask_words.category.values
seen = pd.DataFrame(
    {'words': AMP_words.tolist(),
     'corr_ans': ['right'] * 82,
     'category': AMP_category.tolist()
    })

unseen = pd.DataFrame(
    {'words': memtask_wordlist.tolist(),
     'corr_ans': ['left'] * 50,
     'category': memtask_cats.tolist()
    })

# %%
seen_selection = seen.sample(n=50)
memtask_final = pd.concat([seen_selection,unseen], axis = 0)
memtask_final = memtask_final.sample(frac=1).reset_index(drop=True)
memtask_final.to_csv("exp_files_s19/condition_files/memtask_conditions.csv")

# %%
memtask_final
# Out:
#           words corr_ans          category
# 0     impressed     left       care.virtue
# 1          easy     left  authority.virtue
# 2          want     left    loyalty.virtue
# 3          good    right       care.virtue
# 4     terrorist    right      loyalty.vice
# 5          diet     left   sanctity.virtue
# 6     detention     left     fairness.vice
# 7      staughld     left           nonword
# 8      cabinets     left  authority.virtue
# 9       arrests    right    authority.vice
# 10       wealth     left   sanctity.virtue
# 11         rage     left      loyalty.vice
# 12       heroin     left     sanctity.vice
# 13       energy    right   sanctity.virtue
# 14       scylde     left           nonword
# 15   generosity     left   sanctity.virtue
# 16      attacks    right         care.vice
# 17       rebels    right    authority.vice
# 18     powerful    right  authority.virtue
# 19      loyalty    right    loyalty.virtue
# 20   terrorists    right     fairness.vice
# 21         bomb     left         care.vice
# 22        faith    right   sanctity.virtue
# 23       expand     left       care.virtue
# 24         true     left   fairness.virtue
# 25  appreciated     left  authority.virtue
# 26  authorities     left    authority.vice
# 27     queighld     left           nonword
# 28         hope    right    loyalty.virtue
# 29      restore    right       care.virtue
# ..          ...      ...               ...
# 70      enemies     left     sanctity.vice
# 71     kneighed     left           nonword
# 72   passionate     left    loyalty.virtue
# 73         coup     left      loyalty.vice
# 74      ability    right  authority.virtue
# 75      preighs    right           nonword
# 76    encourage    right  authority.virtue
# 77   protesters    right    authority.vice
# 78      scandal    right     sanctity.vice
# 79      accused    right     fairness.vice
# 80         died    right         care.vice
# 81        weild     left           nonword
# 82     pleasant    right           control
# 83          ban    right      loyalty.vice
# 84         help    right       care.virtue
# 85       agents     left    authority.vice
# 86       safety    right       care.virtue
# 87        doars    right           nonword
# 88     suspects     left         care.vice
# 89        crime    right     fairness.vice
# 90        treat     left   fairness.virtue
# 91      phlaizz     left           nonword
# 92     promises    right   fairness.virtue
# 93   unpleasant    right           control
# 94     military     left    authority.vice
# 95         hand    right   sanctity.virtue
# 96        yacte     left           nonword
# 97       hunger     left     sanctity.vice
# 98      wounded     left         care.vice
# 99        sypht     left           nonword
#
# [100 rows x 3 columns]

# %%
# Out:
# 0.01

# %%
prime_dur
# Out:
# 0.05
